# %% [markdown]
# # IBM Data Science Capstone - Toronto Neighbourhood Clustering Part 2
#
# First starting with the importing of the libraries and variables that wlil be used when we're ready to import and clean the data.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# import k-means from clustering stage
from sklearn.cluster import KMeans

print ('Imported Libraries.')
# Out:
# Imported Libraries.

# %%
# Main vars

# URL where we can find the neighbourhoods
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

geo_url = 'https://cocl.us/Geospatial_data'

# Data Frame to hold the neighbourhood list
tdot_neighbourhoods_df = []
tdot_geocodes_df = []

# %% [markdown]
# ## Merge-a-Plenty
#
# Time to get to work now that our libs and vars have been dealt with.
#
# I needed to split this off into a function to keep things relatively clean. If there's a more efficient, vector-driven way of doing this, please leave a comment I'd be happy to explore further!

# %%
# Data Cleansing Functions

# postcode_merge: take repeated postal codes and combine the neighbourhoods
def postcode_merge(df):
    
    # Vars needed for processing
    return_df, multi_postcode_df, duplicate_postcodes_list = [], [], []
    
    # Create list of postal codes we need to merge
    duplicate_postcodes_df = df.groupby(['Postcode','Borough']).count() > 1
    duplicate_postcodes_df = duplicate_postcodes_df[duplicate_postcodes_df['Neighbourhood'] == True]
    duplicate_postcodes_df.reset_index(inplace=True)
    duplicate_postcodes_list = duplicate_postcodes_df['Postcode'].to_numpy();
    
    # Split dataframes into done pile and merge pile
    return_df = df[~df['Postcode'].isin(duplicate_postcodes_list)][['Postcode','Borough','Neighbourhood']]
    multi_postcode_df = df[df['Postcode'].isin(duplicate_postcodes_list)][['Postcode','Borough','Neighbourhood']]
     
    # Iterate through the duplicate postcode list, NOT the dataframes themselves
    for postcode in duplicate_postcodes_list:

        # Don't repeat if we already processed the postcal code
        if return_df[return_df['Postcode'] == postcode].shape[0] == 0:
            
            # Join the neighbourhoods w/ matching postal code, sort list by neighbourhood name
            append_postcode = postcode
            append_hood =  ', '.join(sorted(map(str, multi_postcode_df[multi_postcode_df['Postcode'] == postcode]['Neighbourhood'].to_numpy())))
            append_borough = multi_postcode_df[multi_postcode_df['Postcode'] == postcode]['Borough'].unique()[0]
            
            # Add entry to return df
            return_df = return_df.append(pd.DataFrame({'Postcode':append_postcode,'Borough':append_borough,'Neighbourhood':append_hood}, index=[0]), ignore_index=True)
    
    # fix and return the clean list of postalcodes and neighbourhoods
    return return_df.rename(columns={"Postcode": "PostalCode","Neighbourhood":"Neighborhood"});
        

print ("functions compiled.")
# Out:
# functions compiled.

# %% [markdown]
# ## Read and clean the data
#
# It's now time to scrape the web page and clean up the data. I used Pandas to scrape but I would like to retry this one day soon using Beautiful Soup (Note to self: Google it).

# %%
# Read the Wikipedia data
tdot_neighbourhoods_df = pd.read_html(url)[0]

# Rule 1: Drop unassigned boroughs
tdot_neighbourhoods_df.drop( tdot_neighbourhoods_df[ tdot_neighbourhoods_df['Borough'] == 'Not assigned' ].index , inplace=True)

# Rule 2: Merge the repeated postal codes
tdot_neighbourhoods_df = postcode_merge(tdot_neighbourhoods_df)

# Rule 3: Fill unassigned hoods
tdot_neighbourhoods_df['Neighborhood'][tdot_neighbourhoods_df['Neighborhood'] == 'Not assigned'] = tdot_neighbourhoods_df['Borough'];

# Just some final sorting touches
tdot_neighbourhoods_df.sort_values(by=['Borough','Neighborhood'], inplace=True)
tdot_neighbourhoods_df.reset_index(drop=True, inplace=True)
print ("")

# %% [markdown]
# ## Toronto Neighbourhoods by Postal Code
#
# The end result with all cleansing in the rearview mirror...

# %%
tdot_neighbourhoods_df
# Out:
#     PostalCode           Borough  \
# 0          M4S   Central Toronto
# 1          M4P   Central Toronto
# 2          M4V   Central Toronto
# 3          M5P   Central Toronto
# 4          M4N   Central Toronto
# 5          M4T   Central Toronto
# 6          M5R   Central Toronto
# 7          M4R   Central Toronto
# 8          M5N   Central Toronto
# 9          M5H  Downtown Toronto
# 10         M5V  Downtown Toronto
# 11         M5E  Downtown Toronto
# 12         M4X  Downtown Toronto
# 13         M5G  Downtown Toronto
# 14         M5T  Downtown Toronto
# 15         M6G  Downtown Toronto
# 16         M4Y  Downtown Toronto
# 17         M5L  Downtown Toronto
# 18         M5K  Downtown Toronto
# 19         M5X  Downtown Toronto
# 20         M5B  Downtown Toronto
# 21         M5S  Downtown Toronto
# 22         M5A  Downtown Toronto
# 23         M5J  Downtown Toronto
# 24         M7A  Downtown Toronto
# 25         M4W  Downtown Toronto
# 26         M5C  Downtown Toronto
# 27         M5W  Downtown Toronto
# 28         M7Y      East Toronto
# 29         M4L      East Toronto
# 30         M4K      East Toronto
# 31         M4M      East Toronto
# 32         M4E      East Toronto
# 33         M4J         East York
# 34         M4G         East York
# 35         M4B         East York
# 36         M4H         East York
# 37         M4C         East York
# 38         M9V         Etobicoke
# 39         M8W         Etobicoke
# 40         M9C         Etobicoke
# 41         M9B         Etobicoke
# 42         M8V         Etobicoke
# 43         M8Y         Etobicoke
# 44         M9R         Etobicoke
# 45         M8Z         Etobicoke
# 46         M8X         Etobicoke
# 47         M9W         Etobicoke
# 48         M9P         Etobicoke
# 49         M7R       Mississauga
# 50         M3H        North York
# 51         M2K        North York
# 52         M5M        North York
# 53         M3K        North York
# 54         M3B        North York
# 55         M3C        North York
# 56         M3M        North York
# 57         M3N        North York
# 58         M3L        North York
# 59         M6L        North York
# 60         M9M        North York
# 61         M2J        North York
# 62         M6B        North York
# 63         M2H        North York
# 64         M9L        North York
# 65         M6A        North York
# 66         M2M        North York
# 67         M3J        North York
# 68         M3A        North York
# 69         M2L        North York
# 70         M4A        North York
# 71         M2N        North York
# 72         M2R        North York
# 73         M2P        North York
# 74         M9A      Queen's Park
# 75         M1S       Scarborough
# 76         M1V       Scarborough
# 77         M1N       Scarborough
# 78         M1H       Scarborough
# 79         M1L       Scarborough
# 80         M1T       Scarborough
# 81         M1M       Scarborough
# 82         M1P       Scarborough
# 83         M1K       Scarborough
# 84         M1E       Scarborough
# 85         M1C       Scarborough
# 86         M1W       Scarborough
# 87         M1B       Scarborough
# 88         M1R       Scarborough
# 89         M1J       Scarborough
# 90         M1X       Scarborough
# 91         M1G       Scarborough
# 92         M6K      West Toronto
# 93         M6H      West Toronto
# 94         M6P      West Toronto
# 95         M6J      West Toronto
# 96         M6R      West Toronto
# 97         M6S      West Toronto
# 98         M6E              York
# 99         M6M              York
# 100        M6C              York
# 101        M6N              York
# 102        M9N              York
#
#                                           Neighborhood
# 0                                           Davisville
# 1                                     Davisville North
# 2    Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 3                  Forest Hill North, Forest Hill West
# 4                                        Lawrence Park
# 5                          Moore Park, Summerhill East
# 6                  North Midtown, The Annex, Yorkville
# 7                                   North Toronto West
# 8                                             Roselawn
# 9                             Adelaide, King, Richmond
# 10   Bathurst Quay, CN Tower, Harbourfront West, Is...
# 11                                         Berczy Park
# 12                         Cabbagetown, St. James Town
# 13                                  Central Bay Street
# 14           Chinatown, Grange Park, Kensington Market
# 15                                            Christie
# 16                                Church and Wellesley
# 17                      Commerce Court, Victoria Hotel
# 18            Design Exchange, Toronto Dominion Centre
# 19              First Canadian Place, Underground city
# 20                            Garden District, Ryerson
# 21                      Harbord, University of Toronto
# 22                                        Harbourfront
# 23   Harbourfront East, Toronto Islands, Union Station
# 24                                        Queen's Park
# 25                                            Rosedale
# 26                                      St. James Town
# 27                     Stn A PO Boxes 25 The Esplanade
# 28   Business Reply Mail Processing Centre 969 Eastern
# 29                      India Bazaar, The Beaches West
# 30                        Riverdale, The Danforth West
# 31                                     Studio District
# 32                                         The Beaches
# 33                                        East Toronto
# 34                                             Leaside
# 35                     Parkview Hill, Woodbine Gardens
# 36                                    Thorncliffe Park
# 37                                    Woodbine Heights
# 38   Albion Gardens, Beaumond Heights, Humbergate, ...
# 39                              Alderwood, Long Branch
# 40   Bloordale Gardens, Eringate, Markland Wood, Ol...
# 41   Cloverdale, Islington, Martin Grove, Princess ...
# 42        Humber Bay Shores, Mimico South, New Toronto
# 43   Humber Bay, King's Mill Park, Kingsway Park So...
# 44   Kingsview Village, Martin Grove Gardens, Richv...
# 45   Kingsway Park South West, Mimico NW, Royal Yor...
# 46       Montgomery Road, Old Mill North, The Kingsway
# 47                                           Northwest
# 48                                           Westmount
# 49               Canada Post Gateway Processing Centre
# 50     Bathurst Manor, Downsview North, Wilson Heights
# 51                                     Bayview Village
# 52                   Bedford Park, Lawrence Manor East
# 53                         CFB Toronto, Downsview East
# 54                                     Don Mills North
# 55                    Don Mills South, Flemingdon Park
# 56                                   Downsview Central
# 57                                 Downsview Northwest
# 58                                      Downsview West
# 59                  Downsview, North Park, Upwood Park
# 60                                    Emery, Humberlea
# 61                        Fairview, Henry Farm, Oriole
# 62                                           Glencairn
# 63                                   Hillcrest Village
# 64                                       Humber Summit
# 65                    Lawrence Heights, Lawrence Manor
# 66                             Newtonbrook, Willowdale
# 67                     Northwood Park, York University
# 68                                           Parkwoods
# 69                            Silver Hills, York Mills
# 70                                    Victoria Village
# 71                                    Willowdale South
# 72                                     Willowdale West
# 73                                     York Mills West
# 74                                        Queen's Park
# 75                                           Agincourt
# 76   Agincourt North, L'Amoreaux East, Milliken, St...
# 77                         Birch Cliff, Cliffside West
# 78                                           Cedarbrae
# 79                     Clairlea, Golden Mile, Oakridge
# 80             Clarks Corners, Sullivan, Tam O'Shanter
# 81     Cliffcrest, Cliffside, Scarborough Village West
# 82   Dorset Park, Scarborough Town Centre, Wexford ...
# 83         East Birchmount Park, Ionview, Kennedy Park
# 84                   Guildwood, Morningside, West Hill
# 85              Highland Creek, Port Union, Rouge Hill
# 86                                     L'Amoreaux West
# 87                                      Malvern, Rouge
# 88                                   Maryvale, Wexford
# 89                                 Scarborough Village
# 90                                         Upper Rouge
# 91                                              Woburn
# 92        Brockton, Exhibition Place, Parkdale Village
# 93                        Dovercourt Village, Dufferin
# 94                       High Park, The Junction South
# 95                            Little Portugal, Trinity
# 96                              Parkdale, Roncesvalles
# 97                                  Runnymede, Swansea
# 98                                 Caledonia-Fairbanks
# 99      Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 100                                 Humewood-Cedarvale
# 101                      Runnymede, The Junction North
# 102                                             Weston

# %% [markdown]
# ### Lets dbl-check the row count
#
# We'll check the row count using .shape

# %%
print ("Number of rows: ", tdot_neighbourhoods_df.shape[0])
# Out:
# Number of rows:  103

# %% [markdown]
# ## Geocoding the Toronto Postal Codes
# This code was supplied by IBM and modified / scaled up.  The geocodeer library was etremely unreliable - replaced with CSV.

# %%
# import geocoder
#!pip install --upgrade geocoder

#import geocoder 


#def get_coords(postal_code):

    # initialize your variable to None
#    lat_lng_coords = None

    # loop until you get the coordinates
 #   while(lat_lng_coords is None):
  #      print('{}, Toronto, Ontario'.format(postal_code))
   #    print (g.latlng)
    #    lat_lng_coords = g.latlng
    
    #return [lat_lng_coords[0], lat_lng_coords[1]];

#tdot_neighbourhoods_df['Latitude','Longitude'][0] = get_coords(tdot_neighbourhoods_df['PostalCode'][0])

#print ("Done.")
#tdot_neighbourhoods_df

# %%
tdot_geocodes_df = pd.read_csv(geo_url)

# %%
# Merge the dataframes by using the postal codes

tdot_geocodes_df.rename(columns={'Postal Code':'PostalCode'}, inplace=True)
tdot_neighbourhoods_df = pd.merge(tdot_neighbourhoods_df, tdot_geocodes_df, on='PostalCode')
tdot_neighbourhoods_df
# Out:
#     PostalCode           Borough  \
# 0          M4S   Central Toronto
# 1          M4P   Central Toronto
# 2          M4V   Central Toronto
# 3          M5P   Central Toronto
# 4          M4N   Central Toronto
# 5          M4T   Central Toronto
# 6          M5R   Central Toronto
# 7          M4R   Central Toronto
# 8          M5N   Central Toronto
# 9          M5H  Downtown Toronto
# 10         M5V  Downtown Toronto
# 11         M5E  Downtown Toronto
# 12         M4X  Downtown Toronto
# 13         M5G  Downtown Toronto
# 14         M5T  Downtown Toronto
# 15         M6G  Downtown Toronto
# 16         M4Y  Downtown Toronto
# 17         M5L  Downtown Toronto
# 18         M5K  Downtown Toronto
# 19         M5X  Downtown Toronto
# 20         M5B  Downtown Toronto
# 21         M5S  Downtown Toronto
# 22         M5A  Downtown Toronto
# 23         M5J  Downtown Toronto
# 24         M7A  Downtown Toronto
# 25         M4W  Downtown Toronto
# 26         M5C  Downtown Toronto
# 27         M5W  Downtown Toronto
# 28         M7Y      East Toronto
# 29         M4L      East Toronto
# 30         M4K      East Toronto
# 31         M4M      East Toronto
# 32         M4E      East Toronto
# 33         M4J         East York
# 34         M4G         East York
# 35         M4B         East York
# 36         M4H         East York
# 37         M4C         East York
# 38         M9V         Etobicoke
# 39         M8W         Etobicoke
# 40         M9C         Etobicoke
# 41         M9B         Etobicoke
# 42         M8V         Etobicoke
# 43         M8Y         Etobicoke
# 44         M9R         Etobicoke
# 45         M8Z         Etobicoke
# 46         M8X         Etobicoke
# 47         M9W         Etobicoke
# 48         M9P         Etobicoke
# 49         M7R       Mississauga
# 50         M3H        North York
# 51         M2K        North York
# 52         M5M        North York
# 53         M3K        North York
# 54         M3B        North York
# 55         M3C        North York
# 56         M3M        North York
# 57         M3N        North York
# 58         M3L        North York
# 59         M6L        North York
# 60         M9M        North York
# 61         M2J        North York
# 62         M6B        North York
# 63         M2H        North York
# 64         M9L        North York
# 65         M6A        North York
# 66         M2M        North York
# 67         M3J        North York
# 68         M3A        North York
# 69         M2L        North York
# 70         M4A        North York
# 71         M2N        North York
# 72         M2R        North York
# 73         M2P        North York
# 74         M9A      Queen's Park
# 75         M1S       Scarborough
# 76         M1V       Scarborough
# 77         M1N       Scarborough
# 78         M1H       Scarborough
# 79         M1L       Scarborough
# 80         M1T       Scarborough
# 81         M1M       Scarborough
# 82         M1P       Scarborough
# 83         M1K       Scarborough
# 84         M1E       Scarborough
# 85         M1C       Scarborough
# 86         M1W       Scarborough
# 87         M1B       Scarborough
# 88         M1R       Scarborough
# 89         M1J       Scarborough
# 90         M1X       Scarborough
# 91         M1G       Scarborough
# 92         M6K      West Toronto
# 93         M6H      West Toronto
# 94         M6P      West Toronto
# 95         M6J      West Toronto
# 96         M6R      West Toronto
# 97         M6S      West Toronto
# 98         M6E              York
# 99         M6M              York
# 100        M6C              York
# 101        M6N              York
# 102        M9N              York
#
#                                           Neighborhood   Latitude  Longitude
# 0                                           Davisville  43.704324 -79.388790
# 1                                     Davisville North  43.712751 -79.390197
# 2    Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 3                  Forest Hill North, Forest Hill West  43.696948 -79.411307
# 4                                        Lawrence Park  43.728020 -79.388790
# 5                          Moore Park, Summerhill East  43.689574 -79.383160
# 6                  North Midtown, The Annex, Yorkville  43.672710 -79.405678
# 7                                   North Toronto West  43.715383 -79.405678
# 8                                             Roselawn  43.711695 -79.416936
# 9                             Adelaide, King, Richmond  43.650571 -79.384568
# 10   Bathurst Quay, CN Tower, Harbourfront West, Is...  43.628947 -79.394420
# 11                                         Berczy Park  43.644771 -79.373306
# 12                         Cabbagetown, St. James Town  43.667967 -79.367675
# 13                                  Central Bay Street  43.657952 -79.387383
# 14           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 15                                            Christie  43.669542 -79.422564
# 16                                Church and Wellesley  43.665860 -79.383160
# 17                      Commerce Court, Victoria Hotel  43.648198 -79.379817
# 18            Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 19              First Canadian Place, Underground city  43.648429 -79.382280
# 20                            Garden District, Ryerson  43.657162 -79.378937
# 21                      Harbord, University of Toronto  43.662696 -79.400049
# 22                                        Harbourfront  43.654260 -79.360636
# 23   Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 24                                        Queen's Park  43.662301 -79.389494
# 25                                            Rosedale  43.679563 -79.377529
# 26                                      St. James Town  43.651494 -79.375418
# 27                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 28   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 29                      India Bazaar, The Beaches West  43.668999 -79.315572
# 30                        Riverdale, The Danforth West  43.679557 -79.352188
# 31                                     Studio District  43.659526 -79.340923
# 32                                         The Beaches  43.676357 -79.293031
# 33                                        East Toronto  43.685347 -79.338106
# 34                                             Leaside  43.709060 -79.363452
# 35                     Parkview Hill, Woodbine Gardens  43.706397 -79.309937
# 36                                    Thorncliffe Park  43.705369 -79.349372
# 37                                    Woodbine Heights  43.695344 -79.318389
# 38   Albion Gardens, Beaumond Heights, Humbergate, ...  43.739416 -79.588437
# 39                              Alderwood, Long Branch  43.602414 -79.543484
# 40   Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 41   Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 42        Humber Bay Shores, Mimico South, New Toronto  43.605647 -79.501321
# 43   Humber Bay, King's Mill Park, Kingsway Park So...  43.636258 -79.498509
# 44   Kingsview Village, Martin Grove Gardens, Richv...  43.688905 -79.554724
# 45   Kingsway Park South West, Mimico NW, Royal Yor...  43.628841 -79.520999
# 46       Montgomery Road, Old Mill North, The Kingsway  43.653654 -79.506944
# 47                                           Northwest  43.706748 -79.594054
# 48                                           Westmount  43.696319 -79.532242
# 49               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 50     Bathurst Manor, Downsview North, Wilson Heights  43.754328 -79.442259
# 51                                     Bayview Village  43.786947 -79.385975
# 52                   Bedford Park, Lawrence Manor East  43.733283 -79.419750
# 53                         CFB Toronto, Downsview East  43.737473 -79.464763
# 54                                     Don Mills North  43.745906 -79.352188
# 55                    Don Mills South, Flemingdon Park  43.725900 -79.340923
# 56                                   Downsview Central  43.728496 -79.495697
# 57                                 Downsview Northwest  43.761631 -79.520999
# 58                                      Downsview West  43.739015 -79.506944
# 59                  Downsview, North Park, Upwood Park  43.713756 -79.490074
# 60                                    Emery, Humberlea  43.724766 -79.532242
# 61                        Fairview, Henry Farm, Oriole  43.778517 -79.346556
# 62                                           Glencairn  43.709577 -79.445073
# 63                                   Hillcrest Village  43.803762 -79.363452
# 64                                       Humber Summit  43.756303 -79.565963
# 65                    Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 66                             Newtonbrook, Willowdale  43.789053 -79.408493
# 67                     Northwood Park, York University  43.767980 -79.487262
# 68                                           Parkwoods  43.753259 -79.329656
# 69                            Silver Hills, York Mills  43.757490 -79.374714
# 70                                    Victoria Village  43.725882 -79.315572
# 71                                    Willowdale South  43.770120 -79.408493
# 72                                     Willowdale West  43.782736 -79.442259
# 73                                     York Mills West  43.752758 -79.400049
# 74                                        Queen's Park  43.667856 -79.532242
# 75                                           Agincourt  43.794200 -79.262029
# 76   Agincourt North, L'Amoreaux East, Milliken, St...  43.815252 -79.284577
# 77                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 78                                           Cedarbrae  43.773136 -79.239476
# 79                     Clairlea, Golden Mile, Oakridge  43.711112 -79.284577
# 80             Clarks Corners, Sullivan, Tam O'Shanter  43.781638 -79.304302
# 81     Cliffcrest, Cliffside, Scarborough Village West  43.716316 -79.239476
# 82   Dorset Park, Scarborough Town Centre, Wexford ...  43.757410 -79.273304
# 83         East Birchmount Park, Ionview, Kennedy Park  43.727929 -79.262029
# 84                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 85              Highland Creek, Port Union, Rouge Hill  43.784535 -79.160497
# 86                                     L'Amoreaux West  43.799525 -79.318389
# 87                                      Malvern, Rouge  43.806686 -79.194353
# 88                                   Maryvale, Wexford  43.750072 -79.295849
# 89                                 Scarborough Village  43.744734 -79.239476
# 90                                         Upper Rouge  43.836125 -79.205636
# 91                                              Woburn  43.770992 -79.216917
# 92        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 93                        Dovercourt Village, Dufferin  43.669005 -79.442259
# 94                       High Park, The Junction South  43.661608 -79.464763
# 95                            Little Portugal, Trinity  43.647927 -79.419750
# 96                              Parkdale, Roncesvalles  43.648960 -79.456325
# 97                                  Runnymede, Swansea  43.651571 -79.484450
# 98                                 Caledonia-Fairbanks  43.689026 -79.453512
# 99      Del Ray, Keelesdale, Mount Dennis, Silverthorn  43.691116 -79.476013
# 100                                 Humewood-Cedarvale  43.693781 -79.428191
# 101                      Runnymede, The Junction North  43.673185 -79.487262
# 102                                             Weston  43.706876 -79.518188

# %% [markdown]
# I hope you enjoyed it!
