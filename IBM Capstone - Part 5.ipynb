# %% [markdown]
# # IBM Data Science Capstone - Toronto / Vancouver Neighbourhood Match Maker
#
# <br>&nbsp;
# <br>&nbsp;
# <br>&nbsp;
# ## Note re: Folium Maps!
# To view folium maps, use the nbviewer URL for this file: https://nbviewer.jupyter.org/github/g3clarke/Coursera_Capstone/blob/master/IBM%20Capstone%20-%20Toronto%20Neighbourhood%20Clustering%20Part%203.ipynb
# <br>&nbsp;
# <br>&nbsp;
# <br>&nbsp;
# <br>&nbsp;
# <br>&nbsp;
#
# This is for anyone planning to move from Toronto to Vancouver who is looking to plant their roots in a simialar neighbourhood to their current home in the Six (Toronto).
#
# We will gather all geographical inforamtion about the two cities as well as the popular venues nearby to make sure a move can feel as close to home as possible in what I believe are two very different cities given the climate and location.
#
# Sources used:
#
# <li>Data from Geonames.org for both cities</li>
#
# Tools used:
# <li>Python libraries</li>
# <li>Foursquare</li>
#
# First starting with the importing of the libraries and variables that wlil be used when we're ready to import and clean the data.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import requests # library to handle requests

print ('Imported Libraries.')
# Out:
# Imported Libraries.

# %%
# Main vars

# URL where we can find the neighbourhoods
tdot_url = 'http://www.geonames.org/postalcode-search.html?q=Toronto&country=CA&adminCode1=ON'
vanc_url = 'http://www.geonames.org/postalcode-search.html?q=Vancouver&country=CA&adminCode1=BC';
    
# Data Frame to hold the neighbourhood list
tdot_neighbourhoods_df = []
vanc_neighbourhoods_df = []

# %% [markdown]
# ## Merge-a-Plenty
#
# Time to get to work now that our libs and vars have been dealt with.
#
# I needed to split this off into a function to keep things relatively clean. If there's a more efficient, vector-driven way of doing this, please leave a comment I'd be happy to explore further!

# %%
# Data Cleansing Functions

# postcode_merge: take repeated postal codes and combine the neighbourhoods
def geocode_merge(df):
    
    second_lines_series = df[~df['Country'].isin(['Canada'])]['Admin3']
    second_lines_df = second_lines_series.to_frame().reset_index()
    second_lines_df['Latitude'] = second_lines_df.apply(lambda row: str(row.Admin3).split('/')[0], axis = 1)
    second_lines_df['Longitude']  = second_lines_df.apply(lambda row: str(row.Admin3).split('/')[-1], axis = 1)
    second_lines_df.drop(second_lines_df.columns[[0,1]],axis=1,inplace=True)

    return_df = df[df['Country'] == 'Canada']
    return_df.reset_index(inplace=True)
    return_df.drop(return_df.columns[[0,1,7]],axis=1,inplace=True)
    return_df.rename(columns={"Code":"PostalCode","Place":"Neighborhood","Admin1": "Province","Admin2":"Borough"},inplace=True);
    return_df = return_df.merge(second_lines_df, left_index=True, right_index=True)
    return_df["Neighborhood"] = return_df["Neighborhood"].astype(str)
    return_df["PostalCode"] = return_df["PostalCode"].astype(str)
    return_df["Country"] = return_df["Country"].astype(str)
    return_df["Province"] = return_df["Province"].astype(str)
    return_df["Borough"] = return_df["Borough"].astype(str)
    return_df["Latitude"] = pd.to_numeric(return_df["Latitude"], downcast="float")
    return_df["Longitude"] = pd.to_numeric(return_df["Longitude"], downcast="float")
    
    return return_df
        
print ("functions compiled.")
# Out:
# functions compiled.

# %% [markdown]
# ## Read and clean the data
#
# It's now time to scrape the web page and clean up the data. I used Pandas to scrape but I would like to retry this one day soon using Beautiful Soup (Note to self: Google it).

# %%
# Read the html source for this data.

tdot_neighbourhoods_df = pd.read_html(tdot_url)[2]
vanc_neighbourhoods_df = pd.read_html(vanc_url)[2]

# %%
tdot_records_df = geocode_merge(tdot_neighbourhoods_df)
vanc_records_df = geocode_merge(vanc_neighbourhoods_df)
vanc_records_df.dtypes
# Out:
# Neighborhood     object
# PostalCode       object
# Country          object
# Province         object
# Borough          object
# Latitude        float32
# Longitude       float32
# dtype: object

# %% [markdown]
# ## Toronto Neighbourhoods by Postal Code
#
# The end result with all cleansing in the rearview mirror...

# %%
tdot_records_df
# Out:
#                                          Neighborhood PostalCode Country  \
# 0                Central Toronto (North Toronto West)        M4R  Canada
# 1   Downtown Toronto (Toronto Dominion Centre / De...        M5K  Canada
# 2   Downtown Toronto (University of Toronto / Harb...        M5S  Canada
# 3                        Downsview East (CFB Toronto)        M3K  Canada
# 4                          East Toronto (The Beaches)        M4E  Canada
# 5                    East Toronto (The Danforth East)        M4J  Canada
# 6                      East Toronto (Studio District)        M4M  Canada
# 7                Central Toronto (Lawrence Park East)        M4N  Canada
# 8                  Central Toronto (Davisville North)        M4P  Canada
# 9                        Central Toronto (Davisville)        M4S  Canada
# 10                        Downtown Toronto (Rosedale)        M4W  Canada
# 11            Downtown Toronto (Church and Wellesley)        M4Y  Canada
# 12                         Downtown Toronto (Ryerson)        M5B  Canada
# 13                  Downtown Toronto (St. James Park)        M5C  Canada
# 14                     Downtown Toronto (Berczy Park)        M5E  Canada
# 15              Downtown Toronto (Central Bay Street)        M5G  Canada
# 16      Downtown Toronto (Richmond / Adelaide / King)        M5H  Canada
# 17                         Central Toronto (Roselawn)        M5N  Canada
# 18                Downtown Toronto (Underground city)        M5X  Canada
# 19                        Downtown Toronto (Christie)        M6G  Canada
# 20       West Toronto (Dufferin / Dovercourt Village)        M6H  Canada
# 21     West Toronto (Parkdale / Roncesvalles Village)        M6R  Canada
# 22  Downtown Toronto (Harbourfront East / Union St...        M5J  Canada
# 23               West Toronto (Rua AÃ¾ores / Trinity)        M6J  Canada
# 24       East Toronto (The Danforth West / Riverdale)        M4K  Canada
# 25     East Toronto (India Bazaar / The Beaches West)        M4L  Canada
# 26     Central Toronto (Moore Park / Summerhill East)        M4T  Canada
# 27    Downtown Toronto (St. James Town / Cabbagetown)        M4X  Canada
# 28  Downtown Toronto (Commerce Court / Victoria Ho...        M5L  Canada
# 29         Central Toronto (Forest Hill North & West)        M5P  Canada
# 30  Central Toronto (The Annex / North Midtown / Y...        M5R  Canada
# 31  Downtown Toronto (Kensington Market / Chinatow...        M5T  Canada
# 32  West Toronto (Brockton / Parkdale Village / Ex...        M6K  Canada
# 33      West Toronto (High Park / The Junction South)        M6P  Canada
# 34        West Toronto (Bloor West Village / Swansea)        M6S  Canada
# 35  Etobicoke (New Toronto / Mimico South / Humber...        M8V  Canada
# 36  Central Toronto (Summerhill West / Rathnelly /...        M4V  Canada
# 37  Downtown Toronto (CN Tower / King and Spadina ...        M5V  Canada
# 38  Downtown Toronto Stn A PO Boxes 25 The Esplana...        M5W  Canada
# 39  East Toronto Business Reply Mail Processing Ce...        M7Y  Canada
# 40   Downtown Toronto (Regent Park / Port of Toronto)        M5A  Canada
#
#    Province  Borough Latitude Longitude
# 0   Ontario  Toronto   43.714   -79.406
# 1   Ontario  Toronto   43.647   -79.382
# 2   Ontario  Toronto   43.663   -79.399
# 3   Ontario  Toronto   43.739   -79.469
# 4   Ontario  Toronto   43.678   -79.294
# 5   Ontario  Toronto   43.687   -79.337
# 6   Ontario  Toronto   43.656   -79.341
# 7   Ontario  Toronto    43.73   -79.394
# 8   Ontario  Toronto   43.714   -79.389
# 9   Ontario  Toronto   43.702   -79.385
# 10  Ontario  Toronto   43.683   -79.373
# 11  Ontario  Toronto   43.666   -79.383
# 12  Ontario  Toronto   43.657   -79.378
# 13  Ontario  Toronto   43.651   -79.376
# 14  Ontario  Toronto   43.646   -79.375
# 15  Ontario  Toronto   43.656   -79.386
# 16  Ontario  Toronto    43.65   -79.383
# 17  Ontario  Toronto   43.711    -79.42
# 18  Ontario  Toronto   43.649   -79.382
# 19  Ontario  Toronto   43.668   -79.421
# 20  Ontario  Toronto   43.665   -79.438
# 21  Ontario  Toronto   43.647   -79.452
# 22  Ontario  Toronto   43.623   -79.394
# 23  Ontario  Toronto   43.648   -79.418
# 24  Ontario  Toronto    43.68   -79.354
# 25  Ontario  Toronto   43.669   -79.315
# 26  Ontario  Toronto    43.69   -79.385
# 27  Ontario  Toronto   43.668   -79.369
# 28  Ontario  Toronto   43.649   -79.382
# 29  Ontario  Toronto   43.697   -79.412
# 30  Ontario  Toronto   43.674   -79.403
# 31  Ontario  Toronto   43.654   -79.398
# 32  Ontario  Toronto   43.638    -79.43
# 33  Ontario  Toronto    43.66   -79.463
# 34  Ontario  Toronto   43.651   -79.483
# 35  Ontario  Toronto   43.607   -79.501
# 36  Ontario  Toronto   43.686   -79.403
# 37  Ontario  Toronto    43.64   -79.399
# 38  Ontario  Toronto   43.644   -79.379
# 39  Ontario  Toronto    43.78   -79.251
# 40  Ontario  Toronto   43.656   -79.363

# %% [markdown]
# ## Vancouver Neighbourhoods by Postal Code
#
# The end result with all cleansing in the rearview mirror...

# %%
vanc_records_df
# Out:
#                                          Neighborhood PostalCode Country  \
# 0                               Vancouver (Killarney)        V5S  Canada
# 1                  Vancouver (North Hastings-Sunrise)        V5K  Canada
# 2               Vancouver (North Grandview-Woodlands)        V5L  Canada
# 3     Vancouver (SE Kensington / Victoria-Fraserview)        V5P  Canada
# 4               Vancouver (South Renfrew-Collingwood)        V5R  Canada
# 5                     Vancouver (East Mount Pleasant)        V5T  Canada
# 6            Vancouver (East Fairview / South Cambie)        V5Z  Canada
# 7                          Vancouver (South West End)        V6E  Canada
# 8                       Vancouver (Central Kitsilano)        V6K  Canada
# 9                        Vancouver (NW Arbutus Ridge)        V6L  Canada
# 10           Vancouver (Dunbar-Southlands / Musqueam)        V6N  Canada
# 11               Vancouver (West Kitsilano / Jericho)        V6R  Canada
# 12                            Vancouver (SW Downtown)        V6Z  Canada
# 13                         North Vancouver Outer East        V7G  Canada
# 14                         North Vancouver Inner East        V7H  Canada
# 15                       North Vancouver East Central        V7J  Canada
# 16                      North Vancouver North Central        V7K  Canada
# 17                      North Vancouver South Central        V7L  Canada
# 18                  North Vancouver Southwest Central        V7M  Canada
# 19                  North Vancouver Northwest Central        V7N  Canada
# 20                          North Vancouver Southwest        V7P  Canada
# 21                          North Vancouver Northwest        V7R  Canada
# 22                               West Vancouver North        V7S  Canada
# 23                           West Vancouver Southeast        V7T  Canada
# 24                               West Vancouver South        V7V  Canada
# 25                                West Vancouver West        V7W  Canada
# 26                         Vancouver (Bentall Centre)        V7X  Canada
# 27                         Vancouver (Pacific Centre)        V7Y  Canada
# 28  Vancouver (South Hastings-Sunrise / North Renf...        V5M  Canada
# 29  Vancouver (South Grandview-Woodlands / NE Kens...        V5N  Canada
# 30  Vancouver (SE Oakridge / East Marpole / South ...        V5X  Canada
# 31  Vancouver (Waterfront / Coal Harbour / Canada ...        V6C  Canada
# 32          Vancouver (North West End / Stanley Park)        V6G  Canada
# 33  Vancouver (West Fairview / Granville Island / ...        V6H  Canada
# 34  Vancouver (NW Shaughnessy / East Kitsilano / Q...        V6J  Canada
# 35  Vancouver (SE Kerrisdale / SW Oakridge / West ...        V6P  Canada
# 36  Vancouver (Chaldecutt / South University Endow...        V6S  Canada
# 37  Vancouver (West Kensington / NE Riley Park-Lit...        V5V  Canada
# 38  Vancouver (West Mount Pleasant / West Riley Pa...        V5Y  Canada
# 39  Vancouver (South Shaughnessy / NW Oakridge / N...        V6M  Canada
# 40  Vancouver (SE Riley Park-Little Mountain / SW ...        V5W  Canada
# 41                                    Vancouver (UBC)        V6T  Canada
# 42  Vancouver (Strathcona / Chinatown / Downtown E...        V6A  Canada
# 43  Vancouver (NE Downtown / Harbour Centre / Gast...        V6B  Canada
# 44                                         Parksville        V9P  Canada
#
#             Province    Borough Latitude Longitude
# 0   British Columbia  Vancouver   49.218  -123.038
# 1   British Columbia  Vancouver   49.281   -123.04
# 2   British Columbia  Vancouver   49.279  -123.067
# 3   British Columbia  Vancouver   49.222  -123.068
# 4   British Columbia  Vancouver    49.24  -123.041
# 5   British Columbia  Vancouver   49.262  -123.092
# 6   British Columbia  Vancouver   49.248  -123.121
# 7   British Columbia  Vancouver   49.283   -123.13
# 8   British Columbia  Vancouver   49.265  -123.165
# 9   British Columbia  Vancouver    49.25  -123.166
# 10  British Columbia  Vancouver    49.23  -123.189
# 11  British Columbia  Vancouver   49.267  -123.198
# 12  British Columbia  Vancouver   49.277   -123.13
# 13  British Columbia  Vancouver   49.368  -122.928
# 14  British Columbia  Vancouver   49.355   -122.98
# 15  British Columbia  Vancouver   49.362  -123.018
# 16  British Columbia  Vancouver    49.36  -123.038
# 17  British Columbia  Vancouver   49.316  -123.058
# 18  British Columbia  Vancouver   49.322  -123.083
# 19  British Columbia  Vancouver    49.35  -123.068
# 20  British Columbia  Vancouver   49.322  -123.115
# 21  British Columbia  Vancouver   49.378  -123.086
# 22  British Columbia  Vancouver   49.374  -123.186
# 23  British Columbia  Vancouver   49.332  -123.142
# 24  British Columbia  Vancouver    49.34  -123.191
# 25  British Columbia  Vancouver   49.361  -123.263
# 26  British Columbia  Vancouver   49.293  -123.116
# 27  British Columbia  Vancouver   49.282  -123.119
# 28  British Columbia  Vancouver    49.26   -123.04
# 29  British Columbia  Vancouver   49.255  -123.067
# 30  British Columbia  Vancouver   49.216  -123.098
# 31  British Columbia  Vancouver   49.287  -123.116
# 32  British Columbia  Vancouver   49.299  -123.141
# 33  British Columbia  Vancouver   49.256  -123.132
# 34  British Columbia  Vancouver    49.26  -123.146
# 35  British Columbia  Vancouver   49.215   -123.14
# 36  British Columbia  Vancouver   49.249  -123.209
# 37  British Columbia  Vancouver   49.248  -123.091
# 38  British Columbia  Vancouver   49.249   -123.11
# 39  British Columbia  Vancouver   49.234  -123.145
# 40  British Columbia  Vancouver   49.233  -123.092
# 41  British Columbia  Vancouver   49.463  -122.822
# 42  British Columbia  Vancouver   49.278  -123.091
# 43  British Columbia  Vancouver   49.279  -123.114
# 44  British Columbia        NaN   49.316  -124.319

# %% [markdown]
# # Mapping Some Results
# Now let's have some fun with Maps. We start by adding some Folium into the mix.

# %%
import random # library for random number generation

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

print('Additional libraries imported.')
print('Folium installed')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ca-certificates-2020.4.5.2 |       hecda079_0         147 KB  conda-forge
#     certifi-2020.4.5.2         |   py36h9f0ad1d_0         152 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0           conda-forge
#     geopy:           1.22.0-pyh9f0ad1d_0 conda-forge
#     python_abi:      3.6-1_cp36m         conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2020.1.1-0                      --> 2020.4.5.2-hecda079_0     conda-forge
#     certifi:         2020.4.5.1-py36_0               --> 2020.4.5.2-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0               --> 1.1.1g-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# ca-certificates-2020 | 147 KB    | ##################################### | 100%
# certifi-2020.4.5.2   | 152 KB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Additional libraries imported.
# Folium installed

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Foursquare credentials loaded.

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Toronto and Vancouver

# %%
tdot_address = 'Toronto, ON'
geolocator = Nominatim(user_agent="on_explorer")
tdot_location = geolocator.geocode(tdot_address)
tdot_latitude = tdot_location.latitude
tdot_longitude = tdot_location.longitude

vanc_address = 'Vancouver, BC'
geolocator = Nominatim(user_agent="on_explorer")
vanc_location = geolocator.geocode(vanc_address)
vanc_latitude = vanc_location.latitude
vanc_longitude = vanc_location.longitude

print('The geograpical coordinates of Toronto are {}, {}, while the geographical coordinates of Vancouver are {}, {}.'.format(tdot_latitude, tdot_longitude, vanc_latitude, vanc_longitude))
# Out:
# The geograpical coordinates of Toronto are 43.6534817, -79.3839347, while the geographical coordinates of Vancouver are 49.2608724, -123.1139529.

# %% [markdown]
# #### Lets see Toronto

# %%
# create map of Toronto using latitude and longitude values
tdot_map = folium.Map(location=[tdot_latitude, tdot_longitude], zoom_start=13)
tdot_neighborhoods = tdot_records_df;

# add markers to map
for lat, lng, borough, neighborhood in zip(tdot_neighborhoods['Latitude'], tdot_neighborhoods['Longitude'], tdot_neighborhoods['Borough'], tdot_neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(tdot_map)  
    
tdot_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Lets see Vancouver

# %%
# create map of Toronto using latitude and longitude values
vanc_map = folium.Map(location=[vanc_latitude, vanc_longitude], zoom_start=13)
vanc_neighborhoods =  vanc_records_df;

# add markers to map
for lat, lng, borough, neighborhood in zip(vanc_neighborhoods['Latitude'], vanc_neighborhoods['Longitude'], vanc_neighborhoods['Borough'], vanc_neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(vanc_map)  
    
vanc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Venues for each neighbourhood
# This function is compliments of the good folks at IBM to access the Foursquare API that will provide us with venue information.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ### Now cycle through the Neighbourhoods, grabbing venue infomation

# %%
# type your answer here

tdot_venues = getNearbyVenues(names=tdot_neighborhoods['Neighborhood'],
                                   latitudes=tdot_neighborhoods['Latitude'],
                                   longitudes=tdot_neighborhoods['Longitude']
                                  )

vanc_venues = getNearbyVenues(names=vanc_neighborhoods['Neighborhood'],
                                   latitudes=vanc_neighborhoods['Latitude'],
                                   longitudes=vanc_neighborhoods['Longitude']
                                  )
# Out:
# Central Toronto (North Toronto West)
# Downtown Toronto (Toronto Dominion Centre / Design Exchange)
# Downtown Toronto (University of Toronto / Harbord)
# Downsview East (CFB Toronto)
# East Toronto (The Beaches)
# East Toronto (The Danforth East)
# East Toronto (Studio District)
# Central Toronto (Lawrence Park East)
# Central Toronto (Davisville North)
# Central Toronto (Davisville)
# Downtown Toronto (Rosedale)
# Downtown Toronto (Church and Wellesley)
# Downtown Toronto (Ryerson)
# Downtown Toronto (St. James Park)
# Downtown Toronto (Berczy Park)
# Downtown Toronto (Central Bay Street)
# Downtown Toronto (Richmond / Adelaide / King)
# Central Toronto (Roselawn)
# Downtown Toronto (Underground city)
# Downtown Toronto (Christie)
# West Toronto (Dufferin / Dovercourt Village)
# West Toronto (Parkdale / Roncesvalles Village)
# Downtown Toronto (Harbourfront East / Union Station / Toronto Island)
# West Toronto (Rua AÃ¾ores / Trinity)
# East Toronto (The Danforth West / Riverdale)
# East Toronto (India Bazaar / The Beaches West)
# Central Toronto (Moore Park / Summerhill East)
# Downtown Toronto (St. James Town / Cabbagetown)
# Downtown Toronto (Commerce Court / Victoria Hotel)
# Central Toronto (Forest Hill North & West)
# Central Toronto (The Annex / North Midtown / Yorkville)
# Downtown Toronto (Kensington Market / Chinatown / Grange Park)
# West Toronto (Brockton / Parkdale Village / Exhibition Place)
# West Toronto (High Park / The Junction South)
# West Toronto (Bloor West Village / Swansea)
# Etobicoke (New Toronto / Mimico South / Humber Bay Shores)
# Central Toronto (Summerhill West / Rathnelly / South Hill / Forest Hill SE / Deer Park)
# Downtown Toronto (CN Tower / King and Spadina / Railway Lands / Harbourfront West / Bathurst Quay / South Niagara / YTZ)
# Downtown Toronto Stn A PO Boxes 25 The Esplanade (Enclave of M5E)
# East Toronto Business Reply Mail Processing Centre 969 Eastern (Enclave of M4L)
# Downtown Toronto (Regent Park / Port of Toronto)
# Vancouver (Killarney)
# Vancouver (North Hastings-Sunrise)
# Vancouver (North Grandview-Woodlands)
# Vancouver (SE Kensington / Victoria-Fraserview)
# Vancouver (South Renfrew-Collingwood)
# Vancouver (East Mount Pleasant)
# Vancouver (East Fairview / South Cambie)
# Vancouver (South West End)
# Vancouver (Central Kitsilano)
# Vancouver (NW Arbutus Ridge)
# Vancouver (Dunbar-Southlands / Musqueam)
# Vancouver (West Kitsilano / Jericho)
# Vancouver (SW Downtown)
# North Vancouver Outer East
# North Vancouver Inner East
# North Vancouver East Central
# North Vancouver North Central
# North Vancouver South Central
# North Vancouver Southwest Central
# North Vancouver Northwest Central
# North Vancouver Southwest
# North Vancouver Northwest
# West Vancouver North
# West Vancouver Southeast
# West Vancouver South
# West Vancouver West
# Vancouver (Bentall Centre)
# Vancouver (Pacific Centre)
# Vancouver (South Hastings-Sunrise / North Renfrew-Collingwood)
# Vancouver (South Grandview-Woodlands / NE Kensington)
# Vancouver (SE Oakridge / East Marpole / South Sunset)
# Vancouver (Waterfront / Coal Harbour / Canada Place)
# Vancouver (North West End / Stanley Park)
# Vancouver (West Fairview / Granville Island / NE Shaughnessy)
# Vancouver (NW Shaughnessy / East Kitsilano / Quilchena)
# Vancouver (SE Kerrisdale / SW Oakridge / West Marpole)
# Vancouver (Chaldecutt / South University Endowment Lands)
# Vancouver (West Kensington / NE Riley Park-Little Mountain)
# Vancouver (West Mount Pleasant / West Riley Park-Little Mountain)
# Vancouver (South Shaughnessy / NW Oakridge / NE Kerrisdale / SE Arbutus Ridge)
# Vancouver (SE Riley Park-Little Mountain / SW Kensington / NE Oakridge / North Sunset)
# Vancouver (UBC)
# Vancouver (Strathcona / Chinatown / Downtown Eastside)
# Vancouver (NE Downtown / Harbour Centre / Gastown / Yaletown)
# Parksville

# %%
#tdot_venues.groupby('Neighborhood').count()
#vanc_venues.groupby('Neighborhood').count()

# %%
print('There are {} unique Toronto categories and {} unique Vancouver categories.'.format(len(tdot_venues['Venue Category'].unique()),len(vanc_venues['Venue Category'].unique())))
# Out:
# There are 178 unique Toronto categories and 152 unique Vancouver categories.

# %% [markdown]
# ### Analyze each neighbourhood

# %%
# one hot encoding
tdot_onehot = pd.get_dummies(tdot_venues[['Venue Category']], prefix="", prefix_sep="")
vanc_onehot = pd.get_dummies(vanc_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframes
tdot_onehot['Neighborhood'] = tdot_venues['Neighborhood'] 
vanc_onehot['Neighborhood'] = vanc_venues['Neighborhood'] 

# move neighborhood column to the first column
tdot_fixed_columns = [tdot_onehot.columns[-1]] + list(tdot_onehot.columns[:-1])
tdot_onehot = tdot_onehot[tdot_fixed_columns]

vanc_fixed_columns = [vanc_onehot.columns[-1]] + list(vanc_onehot.columns[:-1])
vanc_onehot = vanc_onehot[vanc_fixed_columns]

#tdot_onehot.head()

# %% [markdown]
# This function was provided by the good folks at IBM, for returning the top n venue types per neighbourhood

# %%
tdot_grouped = tdot_onehot.groupby('Neighborhood').mean().reset_index()
vanc_grouped = vanc_onehot.groupby('Neighborhood').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)

    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ### Most Popular Venue Types: Toronto

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# %%
# create a new dataframe
tdot_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
tdot_neighborhoods_venues_sorted['Neighborhood'] = tdot_grouped['Neighborhood']

for ind in np.arange(tdot_grouped.shape[0]):
    tdot_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(tdot_grouped.iloc[ind, :], num_top_venues)

tdot_neighborhoods_venues_sorted.head()
# Out:
#                                      Neighborhood 1st Most Common Venue  \
# 0              Central Toronto (Davisville North)                   Gym
# 1                    Central Toronto (Davisville)           Coffee Shop
# 2      Central Toronto (Forest Hill North & West)      Business Service
# 3            Central Toronto (Lawrence Park East)                  Park
# 4  Central Toronto (Moore Park / Summerhill East)                   Gym
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                 Hotel      Department Store               Dog Run
# 1    Italian Restaurant          Dessert Shop                  Café
# 2                  Park                Lawyer                 Trail
# 3                Lawyer    Photography Studio          Dessert Shop
# 4          Tennis Court                  Park         Grocery Store
#
#   5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 0                  Park     Food & Drink Shop               Breakfast Spot
# 1        Sandwich Place      Sushi Restaurant                  Gas Station
# 2          Dessert Shop  Ethiopian Restaurant            Electronics Store
# 3  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
# 4                 Diner    Falafel Restaurant                  Event Space
#
#          8th Most Common Venue   9th Most Common Venue  \
# 0                    Gastropub  Gluten-free Restaurant
# 1                  Flower Shop       Indian Restaurant
# 2  Eastern European Restaurant     Dumpling Restaurant
# 3          Dumpling Restaurant              Donut Shop
# 4         Ethiopian Restaurant       Electronics Store
#
#         10th Most Common Venue
# 0            Electronics Store
# 1         Fast Food Restaurant
# 2                   Donut Shop
# 3                      Dog Run
# 4  Eastern European Restaurant

# %% [markdown]
# ### Most Popular Venue Types: Vancouver

# %%
# create a new dataframe
vanc_neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
vanc_neighborhoods_venues_sorted['Neighborhood'] = vanc_grouped['Neighborhood']

for ind in np.arange(vanc_grouped.shape[0]):
    vanc_neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(vanc_grouped.iloc[ind, :], num_top_venues)

vanc_neighborhoods_venues_sorted.head()
# Out:
#                         Neighborhood 1st Most Common Venue  \
# 0      North Vancouver North Central                 Trail
# 1          North Vancouver Northwest                 Trail
# 2  North Vancouver Northwest Central                 Trail
# 3      North Vancouver South Central               Butcher
# 4          North Vancouver Southwest           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0              Mountain        Scenic Lookout           Yoga Studio
# 1            Ski Chalet            Restaurant  Fast Food Restaurant
# 2           Yoga Studio           Event Space   Filipino Restaurant
# 3        Breakfast Spot        Sandwich Place   Japanese Restaurant
# 4                 Diner        Discount Store                   Gym
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Event Space                 Field  Fast Food Restaurant
# 1              Mountain   Sporting Goods Shop         Ski Chairlift
# 2                 Field  Fast Food Restaurant        Farmers Market
# 3           Yoga Studio    Falafel Restaurant   Filipino Restaurant
# 4           Bus Station      Greek Restaurant      Toy / Game Store
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0        Farmers Market                  Farm     Falafel Restaurant
# 1          Skating Rink        Scenic Lookout              Ski Trail
# 2                  Farm    Falafel Restaurant                   Fair
# 3                 Field  Fast Food Restaurant         Farmers Market
# 4          Burger Joint  Other Great Outdoors    Japanese Restaurant

# %% [markdown]
# ### Let's cluster the Toronto neighbourhoods to see what we can conclude

# %%
# set number of clusters
kclusters = 4

tdot_grouped_clustering = tdot_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(tdot_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 
# add clustering labels
tdot_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

tdot_merged = tdot_neighborhoods

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
tdot_merged = tdot_merged.join(tdot_neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
tdot_merged
# Out:
#                                          Neighborhood PostalCode Country  \
# 0                Central Toronto (North Toronto West)        M4R  Canada
# 1   Downtown Toronto (Toronto Dominion Centre / De...        M5K  Canada
# 2   Downtown Toronto (University of Toronto / Harb...        M5S  Canada
# 3                        Downsview East (CFB Toronto)        M3K  Canada
# 4                          East Toronto (The Beaches)        M4E  Canada
# 5                    East Toronto (The Danforth East)        M4J  Canada
# 6                      East Toronto (Studio District)        M4M  Canada
# 7                Central Toronto (Lawrence Park East)        M4N  Canada
# 8                  Central Toronto (Davisville North)        M4P  Canada
# 9                        Central Toronto (Davisville)        M4S  Canada
# 10                        Downtown Toronto (Rosedale)        M4W  Canada
# 11            Downtown Toronto (Church and Wellesley)        M4Y  Canada
# 12                         Downtown Toronto (Ryerson)        M5B  Canada
# 13                  Downtown Toronto (St. James Park)        M5C  Canada
# 14                     Downtown Toronto (Berczy Park)        M5E  Canada
# 15              Downtown Toronto (Central Bay Street)        M5G  Canada
# 16      Downtown Toronto (Richmond / Adelaide / King)        M5H  Canada
# 17                         Central Toronto (Roselawn)        M5N  Canada
# 18                Downtown Toronto (Underground city)        M5X  Canada
# 19                        Downtown Toronto (Christie)        M6G  Canada
# 20       West Toronto (Dufferin / Dovercourt Village)        M6H  Canada
# 21     West Toronto (Parkdale / Roncesvalles Village)        M6R  Canada
# 22  Downtown Toronto (Harbourfront East / Union St...        M5J  Canada
# 23               West Toronto (Rua AÃ¾ores / Trinity)        M6J  Canada
# 24       East Toronto (The Danforth West / Riverdale)        M4K  Canada
# 25     East Toronto (India Bazaar / The Beaches West)        M4L  Canada
# 26     Central Toronto (Moore Park / Summerhill East)        M4T  Canada
# 27    Downtown Toronto (St. James Town / Cabbagetown)        M4X  Canada
# 28  Downtown Toronto (Commerce Court / Victoria Ho...        M5L  Canada
# 29         Central Toronto (Forest Hill North & West)        M5P  Canada
# 30  Central Toronto (The Annex / North Midtown / Y...        M5R  Canada
# 31  Downtown Toronto (Kensington Market / Chinatow...        M5T  Canada
# 32  West Toronto (Brockton / Parkdale Village / Ex...        M6K  Canada
# 33      West Toronto (High Park / The Junction South)        M6P  Canada
# 34        West Toronto (Bloor West Village / Swansea)        M6S  Canada
# 35  Etobicoke (New Toronto / Mimico South / Humber...        M8V  Canada
# 36  Central Toronto (Summerhill West / Rathnelly /...        M4V  Canada
# 37  Downtown Toronto (CN Tower / King and Spadina ...        M5V  Canada
# 38  Downtown Toronto Stn A PO Boxes 25 The Esplana...        M5W  Canada
# 39  East Toronto Business Reply Mail Processing Ce...        M7Y  Canada
# 40   Downtown Toronto (Regent Park / Port of Toronto)        M5A  Canada
#
#    Province  Borough   Latitude  Longitude  Cluster Labels  \
# 0   Ontario  Toronto  43.714001 -79.405998             3.0
# 1   Ontario  Toronto  43.646999 -79.382004             3.0
# 2   Ontario  Toronto  43.662998 -79.399002             3.0
# 3   Ontario  Toronto  43.738998 -79.469002             3.0
# 4   Ontario  Toronto  43.678001 -79.293999             3.0
# 5   Ontario  Toronto  43.687000 -79.336998             0.0
# 6   Ontario  Toronto  43.655998 -79.341003             0.0
# 7   Ontario  Toronto  43.730000 -79.393997             2.0
# 8   Ontario  Toronto  43.714001 -79.389000             0.0
# 9   Ontario  Toronto  43.702000 -79.385002             3.0
# 10  Ontario  Toronto  43.682999 -79.373001             0.0
# 11  Ontario  Toronto  43.666000 -79.383003             3.0
# 12  Ontario  Toronto  43.657001 -79.377998             3.0
# 13  Ontario  Toronto  43.651001 -79.375999             3.0
# 14  Ontario  Toronto  43.646000 -79.375000             3.0
# 15  Ontario  Toronto  43.655998 -79.386002             3.0
# 16  Ontario  Toronto  43.650002 -79.383003             3.0
# 17  Ontario  Toronto  43.710999 -79.419998             1.0
# 18  Ontario  Toronto  43.648998 -79.382004             3.0
# 19  Ontario  Toronto  43.667999 -79.420998             0.0
# 20  Ontario  Toronto  43.665001 -79.438004             0.0
# 21  Ontario  Toronto  43.646999 -79.452003             3.0
# 22  Ontario  Toronto  43.623001 -79.393997             0.0
# 23  Ontario  Toronto  43.647999 -79.417999             3.0
# 24  Ontario  Toronto  43.680000 -79.353996             3.0
# 25  Ontario  Toronto  43.668999 -79.315002             3.0
# 26  Ontario  Toronto  43.689999 -79.385002             0.0
# 27  Ontario  Toronto  43.667999 -79.369003             3.0
# 28  Ontario  Toronto  43.648998 -79.382004             3.0
# 29  Ontario  Toronto  43.696999 -79.412003             0.0
# 30  Ontario  Toronto  43.674000 -79.403000             3.0
# 31  Ontario  Toronto  43.653999 -79.398003             3.0
# 32  Ontario  Toronto  43.638000 -79.430000             3.0
# 33  Ontario  Toronto  43.660000 -79.462997             0.0
# 34  Ontario  Toronto  43.651001 -79.483002             3.0
# 35  Ontario  Toronto  43.606998 -79.500999             NaN
# 36  Ontario  Toronto  43.686001 -79.403000             3.0
# 37  Ontario  Toronto  43.639999 -79.399002             3.0
# 38  Ontario  Toronto  43.644001 -79.378998             3.0
# 39  Ontario  Toronto  43.779999 -79.250999             3.0
# 40  Ontario  Toronto  43.655998 -79.362999             3.0
#
#    1st Most Common Venue                     2nd Most Common Venue  \
# 0            Yoga Studio                   Health & Beauty Service
# 1            Coffee Shop                                      Café
# 2                   Café                                Restaurant
# 3                Airport                                Shoe Store
# 4                  Trail                                 Gastropub
# 5                   Park                               Coffee Shop
# 6                    Gym                             Garden Center
# 7                   Park                                    Lawyer
# 8                    Gym                                     Hotel
# 9            Coffee Shop                        Italian Restaurant
# 10                  Park                               Candy Store
# 11               Gay Bar                              Burger Joint
# 12        Clothing Store                                      Café
# 13             Gastropub                                      Café
# 14                  Café                              Cocktail Bar
# 15           Coffee Shop                       Japanese Restaurant
# 16           Coffee Shop                                      Café
# 17          Home Service                            Clothing Store
# 18                  Café                               Coffee Shop
# 19                  Café                             Grocery Store
# 20                  Park                    Furniture / Home Store
# 21   American Restaurant               Eastern European Restaurant
# 22                  Park                               Music Venue
# 23                   Bar                          Asian Restaurant
# 24      Greek Restaurant                        Italian Restaurant
# 25                  Park                      Fast Food Restaurant
# 26                   Gym                              Tennis Court
# 27            Restaurant                                      Café
# 28                  Café                               Coffee Shop
# 29      Business Service                                      Park
# 30        Sandwich Place                                      Café
# 31                  Café                     Vietnamese Restaurant
# 32                  Café                                 Gift Shop
# 33                  Park  Residential Building (Apartment / Condo)
# 34                  Café                        Italian Restaurant
# 35                   NaN                                       NaN
# 36                  Park                        Athletics & Sports
# 37           Coffee Shop                        Italian Restaurant
# 38           Coffee Shop                                     Hotel
# 39            Restaurant                               Coffee Shop
# 40           Coffee Shop                                Restaurant
#
#    3rd Most Common Venue  4th Most Common Venue      5th Most Common Venue  \
# 0     Salon / Barbershop                   Café                 Restaurant
# 1             Restaurant                 Bakery                 Steakhouse
# 2    Japanese Restaurant     Italian Restaurant                  Bookstore
# 3            Coffee Shop             Food Court                  Wine Shop
# 4      Health Food Store                 Bakery                        Pub
# 5       Greek Restaurant      Convenience Store             Cosmetics Shop
# 6        Coworking Space            Coffee Shop                      Diner
# 7     Photography Studio           Dessert Shop       Ethiopian Restaurant
# 8       Department Store                Dog Run                       Park
# 9           Dessert Shop                   Café             Sandwich Place
# 10            Playground          Grocery Store        American Restaurant
# 11           Coffee Shop  General Entertainment         Salon / Barbershop
# 12              Tea Room                Theater         College Rec Center
# 13           Coffee Shop           Cocktail Bar                        Gym
# 14              Beer Bar     Seafood Restaurant                Tailor Shop
# 15                 Plaza             Comic Shop                       Park
# 16   American Restaurant                  Hotel                 Restaurant
# 17             Wine Shop                  Diner         Falafel Restaurant
# 18            Restaurant    American Restaurant         Seafood Restaurant
# 19                  Park            Coffee Shop                Candy Store
# 20         Grocery Store                    Gym                 Smoke Shop
# 21        Breakfast Spot              Gift Shop                  Bookstore
# 22       Harbor / Marina                   Café                      Diner
# 23           Coffee Shop                Brewery        Japanese Restaurant
# 24        Ice Cream Shop            Yoga Studio                       Café
# 25                   Gym          Movie Theater             Sandwich Place
# 26                  Park          Grocery Store                      Diner
# 27    Italian Restaurant            Coffee Shop                     Bakery
# 28            Restaurant    American Restaurant         Seafood Restaurant
# 29                Lawyer                  Trail               Dessert Shop
# 30           Pizza Place              BBQ Joint          Indian Restaurant
# 31    Mexican Restaurant        Organic Grocery                Gaming Cafe
# 32           Coffee Shop         Breakfast Spot                        Gym
# 33     Convenience Store            Event Space       Ethiopian Restaurant
# 34    Falafel Restaurant       Sushi Restaurant  Latin American Restaurant
# 35                   NaN                    NaN                        NaN
# 36    Light Rail Station                   Café                Supermarket
# 37                  Café                   Park       Gym / Fitness Center
# 38   Japanese Restaurant     Italian Restaurant                 Restaurant
# 39    Italian Restaurant            Yoga Studio                       Bank
# 40        Breakfast Spot   Gym / Fitness Center                        Pub
#
#       6th Most Common Venue        7th Most Common Venue  \
# 0                     Diner                Metro Station
# 1      Gym / Fitness Center                        Hotel
# 2                    Bakery        College Arts Building
# 3                     Diner                  Event Space
# 4                 Wine Shop                 Dessert Shop
# 5                   Dog Run           Falafel Restaurant
# 6            Baseball Field                         Park
# 7         Electronics Store  Eastern European Restaurant
# 8         Food & Drink Shop               Breakfast Spot
# 9          Sushi Restaurant                  Gas Station
# 10                    Diner           Falafel Restaurant
# 11               Restaurant                         Café
# 12       Mexican Restaurant                Shopping Mall
# 13           Cosmetics Shop           Italian Restaurant
# 14                Jazz Club                   Restaurant
# 15          Bubble Tea Shop               Sandwich Place
# 16       Seafood Restaurant                          Bar
# 17              Event Space         Ethiopian Restaurant
# 18                   Bakery         Gym / Fitness Center
# 19               Baby Store                    Wine Shop
# 20                     Café                     Pharmacy
# 21              Coffee Shop                 Gourmet Shop
# 22              Event Space         Ethiopian Restaurant
# 23              Record Shop            Korean Restaurant
# 24                      Spa                    Bookstore
# 25               Restaurant                          Pub
# 26       Falafel Restaurant                  Event Space
# 27                  Butcher          Japanese Restaurant
# 28                   Bakery         Gym / Fitness Center
# 29     Ethiopian Restaurant            Electronics Store
# 30             Liquor Store               History Museum
# 31              Record Shop               Farmers Market
# 32                      Bar                    Pet Store
# 33        Electronics Store  Eastern European Restaurant
# 34             Dessert Shop                          Pub
# 35                      NaN                          NaN
# 36             Liquor Store                 Tennis Court
# 37        French Restaurant                  Yoga Studio
# 38  New American Restaurant                  IT Services
# 39            Deli / Bodega            Martial Arts Dojo
# 40                 Pharmacy        Performing Arts Venue
#
#           8th Most Common Venue        9th Most Common Venue  \
# 0                   Coffee Shop               Clothing Store
# 1           Japanese Restaurant                Deli / Bodega
# 2            Chinese Restaurant                   Beer Store
# 3          Ethiopian Restaurant            Electronics Store
# 4                   Event Space         Ethiopian Restaurant
# 5                   Event Space         Ethiopian Restaurant
# 6                       Gay Bar                Deli / Bodega
# 7           Dumpling Restaurant                   Donut Shop
# 8                     Gastropub       Gluten-free Restaurant
# 9                   Flower Shop            Indian Restaurant
# 10                  Event Space         Ethiopian Restaurant
# 11             Ramen Restaurant                          Pub
# 12                    Bookstore               Sandwich Place
# 13          Japanese Restaurant                    Jazz Club
# 14               Farmers Market             Department Store
# 15                         Café                Shopping Mall
# 16       Gluten-free Restaurant             Greek Restaurant
# 17            Electronics Store  Eastern European Restaurant
# 18               Ice Cream Shop               General Travel
# 19                      Dog Run                  Event Space
# 20                       Bakery                         Bank
# 21             Sushi Restaurant                   Restaurant
# 22            Electronics Store  Eastern European Restaurant
# 23                      Dog Run                  Pizza Place
# 24                      Brewery                 Burger Joint
# 25                  Pizza Place                    Pet Store
# 26         Ethiopian Restaurant            Electronics Store
# 27         Caribbean Restaurant            Indian Restaurant
# 28               Ice Cream Shop               General Travel
# 29  Eastern European Restaurant          Dumpling Restaurant
# 30                   Donut Shop                     Pharmacy
# 31                  Fish Market          Dumpling Restaurant
# 32                 Cocktail Bar                 Chiropractor
# 33          Dumpling Restaurant                   Donut Shop
# 34                Burrito Place            Fish & Chips Shop
# 35                          NaN                          NaN
# 36                 Skating Rink                  Coffee Shop
# 37             Ramen Restaurant                      Brewery
# 38          Sporting Goods Shop           Basketball Stadium
# 39               Breakfast Spot                    Bookstore
# 40                         Park           Italian Restaurant
#
#          10th Most Common Venue
# 0            Mexican Restaurant
# 1                  Concert Hall
# 2                      Beer Bar
# 3   Eastern European Restaurant
# 4             Electronics Store
# 5             Electronics Store
# 6   Eastern European Restaurant
# 7                       Dog Run
# 8             Electronics Store
# 9          Fast Food Restaurant
# 10            Electronics Store
# 11                  Pizza Place
# 12            Electronics Store
# 13                   Restaurant
# 14               Breakfast Spot
# 15                 Dessert Shop
# 16         Gym / Fitness Center
# 17          Dumpling Restaurant
# 18                  Pizza Place
# 19         Ethiopian Restaurant
# 20                     Bus Line
# 21                      Butcher
# 22          Dumpling Restaurant
# 23                  Yoga Studio
# 24                   Restaurant
# 25                 Liquor Store
# 26  Eastern European Restaurant
# 27                          Pub
# 28                  Pizza Place
# 29                   Donut Shop
# 30            French Restaurant
# 31                 Cocktail Bar
# 32          Japanese Restaurant
# 33                      Dog Run
# 34                   Restaurant
# 35                          NaN
# 36                 Dance Studio
# 37                   Restaurant
# 38                     Beer Bar
# 39             Sushi Restaurant
# 40            Health Food Store

# %% [markdown]
# ### Let's cluster the Vancouver neighbourhoods to see what we can conclude

# %%
# set number of clusters
kclusters = 4

vanc_grouped_clustering = vanc_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(vanc_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 
# add clustering labels
vanc_neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

vanc_merged = vanc_neighborhoods

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
vanc_merged = vanc_merged.join(vanc_neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
vanc_merged
# Out:
#                                          Neighborhood PostalCode Country  \
# 0                               Vancouver (Killarney)        V5S  Canada
# 1                  Vancouver (North Hastings-Sunrise)        V5K  Canada
# 2               Vancouver (North Grandview-Woodlands)        V5L  Canada
# 3     Vancouver (SE Kensington / Victoria-Fraserview)        V5P  Canada
# 4               Vancouver (South Renfrew-Collingwood)        V5R  Canada
# 5                     Vancouver (East Mount Pleasant)        V5T  Canada
# 6            Vancouver (East Fairview / South Cambie)        V5Z  Canada
# 7                          Vancouver (South West End)        V6E  Canada
# 8                       Vancouver (Central Kitsilano)        V6K  Canada
# 9                        Vancouver (NW Arbutus Ridge)        V6L  Canada
# 10           Vancouver (Dunbar-Southlands / Musqueam)        V6N  Canada
# 11               Vancouver (West Kitsilano / Jericho)        V6R  Canada
# 12                            Vancouver (SW Downtown)        V6Z  Canada
# 13                         North Vancouver Outer East        V7G  Canada
# 14                         North Vancouver Inner East        V7H  Canada
# 15                       North Vancouver East Central        V7J  Canada
# 16                      North Vancouver North Central        V7K  Canada
# 17                      North Vancouver South Central        V7L  Canada
# 18                  North Vancouver Southwest Central        V7M  Canada
# 19                  North Vancouver Northwest Central        V7N  Canada
# 20                          North Vancouver Southwest        V7P  Canada
# 21                          North Vancouver Northwest        V7R  Canada
# 22                               West Vancouver North        V7S  Canada
# 23                           West Vancouver Southeast        V7T  Canada
# 24                               West Vancouver South        V7V  Canada
# 25                                West Vancouver West        V7W  Canada
# 26                         Vancouver (Bentall Centre)        V7X  Canada
# 27                         Vancouver (Pacific Centre)        V7Y  Canada
# 28  Vancouver (South Hastings-Sunrise / North Renf...        V5M  Canada
# 29  Vancouver (South Grandview-Woodlands / NE Kens...        V5N  Canada
# 30  Vancouver (SE Oakridge / East Marpole / South ...        V5X  Canada
# 31  Vancouver (Waterfront / Coal Harbour / Canada ...        V6C  Canada
# 32          Vancouver (North West End / Stanley Park)        V6G  Canada
# 33  Vancouver (West Fairview / Granville Island / ...        V6H  Canada
# 34  Vancouver (NW Shaughnessy / East Kitsilano / Q...        V6J  Canada
# 35  Vancouver (SE Kerrisdale / SW Oakridge / West ...        V6P  Canada
# 36  Vancouver (Chaldecutt / South University Endow...        V6S  Canada
# 37  Vancouver (West Kensington / NE Riley Park-Lit...        V5V  Canada
# 38  Vancouver (West Mount Pleasant / West Riley Pa...        V5Y  Canada
# 39  Vancouver (South Shaughnessy / NW Oakridge / N...        V6M  Canada
# 40  Vancouver (SE Riley Park-Little Mountain / SW ...        V5W  Canada
# 41                                    Vancouver (UBC)        V6T  Canada
# 42  Vancouver (Strathcona / Chinatown / Downtown E...        V6A  Canada
# 43  Vancouver (NE Downtown / Harbour Centre / Gast...        V6B  Canada
# 44                                         Parksville        V9P  Canada
#
#             Province    Borough   Latitude   Longitude  Cluster Labels  \
# 0   British Columbia  Vancouver  49.217999 -123.038002             1.0
# 1   British Columbia  Vancouver  49.280998 -123.040001             1.0
# 2   British Columbia  Vancouver  49.278999 -123.067001             1.0
# 3   British Columbia  Vancouver  49.222000 -123.068001             1.0
# 4   British Columbia  Vancouver  49.240002 -123.041000             1.0
# 5   British Columbia  Vancouver  49.262001 -123.092003             1.0
# 6   British Columbia  Vancouver  49.248001 -123.121002             1.0
# 7   British Columbia  Vancouver  49.283001 -123.129997             1.0
# 8   British Columbia  Vancouver  49.264999 -123.165001             1.0
# 9   British Columbia  Vancouver  49.250000 -123.166000             1.0
# 10  British Columbia  Vancouver  49.230000 -123.189003             1.0
# 11  British Columbia  Vancouver  49.266998 -123.197998             0.0
# 12  British Columbia  Vancouver  49.277000 -123.129997             1.0
# 13  British Columbia  Vancouver  49.368000 -122.928001             NaN
# 14  British Columbia  Vancouver  49.355000 -122.980003             NaN
# 15  British Columbia  Vancouver  49.362000 -123.017998             NaN
# 16  British Columbia  Vancouver  49.360001 -123.038002             1.0
# 17  British Columbia  Vancouver  49.316002 -123.057999             1.0
# 18  British Columbia  Vancouver  49.321999 -123.083000             0.0
# 19  British Columbia  Vancouver  49.349998 -123.068001             3.0
# 20  British Columbia  Vancouver  49.321999 -123.114998             1.0
# 21  British Columbia  Vancouver  49.377998 -123.085999             1.0
# 22  British Columbia  Vancouver  49.374001 -123.185997             NaN
# 23  British Columbia  Vancouver  49.332001 -123.141998             1.0
# 24  British Columbia  Vancouver  49.340000 -123.191002             1.0
# 25  British Columbia  Vancouver  49.361000 -123.263000             3.0
# 26  British Columbia  Vancouver  49.292999 -123.115997             1.0
# 27  British Columbia  Vancouver  49.282001 -123.119003             1.0
# 28  British Columbia  Vancouver  49.259998 -123.040001             1.0
# 29  British Columbia  Vancouver  49.255001 -123.067001             1.0
# 30  British Columbia  Vancouver  49.216000 -123.098000             1.0
# 31  British Columbia  Vancouver  49.286999 -123.115997             1.0
# 32  British Columbia  Vancouver  49.299000 -123.140999             1.0
# 33  British Columbia  Vancouver  49.256001 -123.132004             1.0
# 34  British Columbia  Vancouver  49.259998 -123.146004             1.0
# 35  British Columbia  Vancouver  49.215000 -123.139999             1.0
# 36  British Columbia  Vancouver  49.249001 -123.209000             0.0
# 37  British Columbia  Vancouver  49.248001 -123.091003             1.0
# 38  British Columbia  Vancouver  49.249001 -123.110001             1.0
# 39  British Columbia  Vancouver  49.234001 -123.144997             1.0
# 40  British Columbia  Vancouver  49.233002 -123.092003             1.0
# 41  British Columbia  Vancouver  49.463001 -122.821999             NaN
# 42  British Columbia  Vancouver  49.278000 -123.091003             1.0
# 43  British Columbia  Vancouver  49.278999 -123.113998             1.0
# 44  British Columbia        nan  49.316002 -124.319000             2.0
#
#            1st Most Common Venue          2nd Most Common Venue  \
# 0                       Bus Stop                    Pizza Place
# 1   Theme Park Ride / Attraction                     Theme Park
# 2               Asian Restaurant                           Café
# 3                    Pizza Place                       Pharmacy
# 4              Fish & Chips Shop                          Hotel
# 5               Sushi Restaurant          Vietnamese Restaurant
# 6                       Bus Stop                    Coffee Shop
# 7                         Bakery                          Diner
# 8                    Coffee Shop  Vegetarian / Vegan Restaurant
# 9           Caribbean Restaurant             Italian Restaurant
# 10                  Home Service          Vietnamese Restaurant
# 11                          Park                    Yoga Studio
# 12                          Café                         Bakery
# 13                           NaN                            NaN
# 14                           NaN                            NaN
# 15                           NaN                            NaN
# 16                         Trail                       Mountain
# 17                       Butcher                 Breakfast Spot
# 18                          Park                 Baseball Field
# 19                         Trail                    Yoga Studio
# 20                   Coffee Shop                          Diner
# 21                         Trail                     Ski Chalet
# 22                           NaN                            NaN
# 23                          Bank                       Pharmacy
# 24                  Home Service                    Art Gallery
# 25                         Trail               Tapas Restaurant
# 26                         Plaza                 Breakfast Spot
# 27                         Hotel                   Concert Hall
# 28                      Bus Stop                    Coffee Shop
# 29                  Concert Hall                         Bakery
# 30                          Park              Indian Restaurant
# 31                         Hotel            American Restaurant
# 32                        Garden                          Trail
# 33                Breakfast Spot                       Bus Stop
# 34             Electronics Store                 Breakfast Spot
# 35            Chinese Restaurant                 Sandwich Place
# 36                          Park                    Yoga Studio
# 37                   Coffee Shop                       Bus Stop
# 38            Chinese Restaurant                    Coffee Shop
# 39                      Bus Stop             Chinese Restaurant
# 40            Chinese Restaurant                  Grocery Store
# 41                           NaN                            NaN
# 42                      Pie Shop                     Food Truck
# 43                    Taco Place                 Breakfast Spot
# 44        Thrift / Vintage Store                    Yoga Studio
#
#      3rd Most Common Venue       4th Most Common Venue 5th Most Common Venue  \
# 0            Shopping Mall          Chinese Restaurant          Liquor Store
# 1              Event Space                Soccer Field      Sushi Restaurant
# 2              Coffee Shop                     Brewery               Theater
# 3      Fried Chicken Joint                        Park             Pet Store
# 4                     Park            Asian Restaurant              Bus Stop
# 5     Ethiopian Restaurant                    Pharmacy     Outdoor Sculpture
# 6       Chinese Restaurant                         Gym                  Bank
# 7                Bookstore            Greek Restaurant   Japanese Restaurant
# 8                     Café                 Yoga Studio        Farmers Market
# 9                   Bakery                 Yoga Studio                  Fair
# 10    Fast Food Restaurant                 Event Space   Filipino Restaurant
# 11             Event Space         Filipino Restaurant                 Field
# 12      Mexican Restaurant                       Hotel      Sushi Restaurant
# 13                     NaN                         NaN                   NaN
# 14                     NaN                         NaN                   NaN
# 15                     NaN                         NaN                   NaN
# 16          Scenic Lookout                 Yoga Studio           Event Space
# 17          Sandwich Place         Japanese Restaurant           Yoga Studio
# 18             Yoga Studio                        Fair   Filipino Restaurant
# 19             Event Space         Filipino Restaurant                 Field
# 20          Discount Store                         Gym           Bus Station
# 21              Restaurant        Fast Food Restaurant              Mountain
# 22                     NaN                         NaN                   NaN
# 23            Liquor Store          Mexican Restaurant                  Fair
# 24                    Fair  Financial or Legal Service   Filipino Restaurant
# 25             Yoga Studio                        Fair   Filipino Restaurant
# 26               Irish Pub                   Gastropub     Outdoor Sculpture
# 27              Food Truck            Toy / Game Store            Restaurant
# 28  Furniture / Home Store                      Office          Liquor Store
# 29               Bookstore                        Lake                  Café
# 30              Restaurant         Sporting Goods Shop           Yoga Studio
# 31                    Café                         Spa   Japanese Restaurant
# 32                    Park           Outdoor Sculpture           Yoga Studio
# 33           Historic Site                 Pizza Place                  Café
# 34        Sushi Restaurant                  Restaurant   Japanese Restaurant
# 35        Sushi Restaurant                 Pizza Place       Thai Restaurant
# 36             Event Space         Filipino Restaurant                 Field
# 37   Vietnamese Restaurant         Filipino Restaurant           Pizza Place
# 38            Dessert Shop              Discount Store    Falafel Restaurant
# 39       Electronics Store            Asian Restaurant           Coffee Shop
# 40             Pizza Place                    Tea Room                 Diner
# 41                     NaN                         NaN                   NaN
# 42                    Park                 Coffee Shop                   Pub
# 43            Burger Joint                Hockey Arena            Restaurant
# 44             Event Space         Filipino Restaurant                 Field
#
#          6th Most Common Venue 7th Most Common Venue  \
# 0               Sandwich Place    Salon / Barbershop
# 1               Sandwich Place           Bus Station
# 2                  Pizza Place      Sushi Restaurant
# 3            Convenience Store       Motorcycle Shop
# 4                          Bar    Falafel Restaurant
# 5                         Park         Grocery Store
# 6                 Dessert Shop                  Café
# 7               Farmers Market               Gay Bar
# 8          Japanese Restaurant            Food Truck
# 9          Filipino Restaurant                 Field
# 10                       Field        Farmers Market
# 11        Fast Food Restaurant        Farmers Market
# 12            Greek Restaurant            Taco Place
# 13                         NaN                   NaN
# 14                         NaN                   NaN
# 15                         NaN                   NaN
# 16                       Field  Fast Food Restaurant
# 17          Falafel Restaurant   Filipino Restaurant
# 18                       Field  Fast Food Restaurant
# 19        Fast Food Restaurant        Farmers Market
# 20            Greek Restaurant      Toy / Game Store
# 21         Sporting Goods Shop         Ski Chairlift
# 22                         NaN                   NaN
# 23         Filipino Restaurant                 Field
# 24                       Field  Fast Food Restaurant
# 25                       Field  Fast Food Restaurant
# 26            Airport Terminal   American Restaurant
# 27              Cosmetics Shop           Coffee Shop
# 28          Chinese Restaurant        Sandwich Place
# 29          Child Care Service           Music Venue
# 30                 Event Space                 Field
# 31                       Plaza           Yoga Studio
# 32        Fast Food Restaurant        Farmers Market
# 33                      Bakery   Japanese Restaurant
# 34                Tennis Court       Thai Restaurant
# 35                 Coffee Shop              Bus Stop
# 36        Fast Food Restaurant        Farmers Market
# 37           Electronics Store    Chinese Restaurant
# 38  Financial or Legal Service   Filipino Restaurant
# 39            Sushi Restaurant           Yoga Studio
# 40                     Dog Run           Coffee Shop
# 41                         NaN                   NaN
# 42                  Restaurant        Sandwich Place
# 43                 Coffee Shop                Museum
# 44        Fast Food Restaurant        Farmers Market
#
#             8th Most Common Venue       9th Most Common Venue  \
# 0                Sushi Restaurant                   Juice Bar
# 1                    Burger Joint                        Farm
# 2               Convenience Store           Fish & Chips Shop
# 3                      Restaurant              Sandwich Place
# 4      Financial or Legal Service         Filipino Restaurant
# 5                     Pizza Place                Cocktail Bar
# 6                    Liquor Store          Light Rail Station
# 7       Middle Eastern Restaurant          Miscellaneous Shop
# 8                    Burger Joint                Liquor Store
# 9            Fast Food Restaurant              Farmers Market
# 10                           Farm          Falafel Restaurant
# 11                           Farm          Falafel Restaurant
# 12                  Movie Theater                        Pool
# 13                            NaN                         NaN
# 14                            NaN                         NaN
# 15                            NaN                         NaN
# 16                 Farmers Market                        Farm
# 17                          Field        Fast Food Restaurant
# 18                 Farmers Market                        Farm
# 19                           Farm          Falafel Restaurant
# 20                   Burger Joint        Other Great Outdoors
# 21                   Skating Rink              Scenic Lookout
# 22                            NaN                         NaN
# 23           Fast Food Restaurant              Farmers Market
# 24                 Farmers Market                        Farm
# 25                 Farmers Market                        Farm
# 26               Asian Restaurant          Falafel Restaurant
# 27              Mobile Phone Shop              Clothing Store
# 28               Storage Facility                  Restaurant
# 29                           Park                Skating Rink
# 30           Fast Food Restaurant              Farmers Market
# 31                    Coffee Shop              Sandwich Place
# 32                           Farm          Falafel Restaurant
# 33                           Farm  Financial or Legal Service
# 34  Paper / Office Supplies Store      Furniture / Home Store
# 35                   Dessert Shop             Bubble Tea Shop
# 36                           Farm          Falafel Restaurant
# 37               Malay Restaurant              Sandwich Place
# 38                          Field        Fast Food Restaurant
# 39                           Farm         Filipino Restaurant
# 40           Fast Food Restaurant                       Field
# 41                            NaN                         NaN
# 42             Seafood Restaurant                 Cheese Shop
# 43                 Soccer Stadium                     Stadium
# 44                           Farm          Falafel Restaurant
#
#         10th Most Common Venue
# 0               Farmers Market
# 1                       Market
# 2           Chinese Restaurant
# 3    Middle Eastern Restaurant
# 4                        Field
# 5                          Pub
# 6             Sushi Restaurant
# 7           Seafood Restaurant
# 8                   Restaurant
# 9                         Farm
# 10                        Fair
# 11                        Fair
# 12   Middle Eastern Restaurant
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16          Falafel Restaurant
# 17              Farmers Market
# 18          Falafel Restaurant
# 19                        Fair
# 20         Japanese Restaurant
# 21                   Ski Trail
# 22                         NaN
# 23                        Farm
# 24          Falafel Restaurant
# 25          Falafel Restaurant
# 26  Financial or Legal Service
# 27                  Steakhouse
# 28         Japanese Restaurant
# 29         Arts & Crafts Store
# 30                        Farm
# 31                   Cafeteria
# 32                        Fair
# 33         Filipino Restaurant
# 34           Indian Restaurant
# 35                 Gas Station
# 36                        Fair
# 37                  Restaurant
# 38              Farmers Market
# 39                       Field
# 40                    Bus Stop
# 41                         NaN
# 42                        Café
# 43                         Spa
# 44                        Fair

# %% [markdown]
# # Conclusions / Insights
#
# <ul>
#     <li>What I love about <b>Rosedale</b> is that it is by and large the most outdoor recreation-friendly neighbourhood in the Toronto downtown core, relative to its surroundings, with enough outdoor venue types to set it apart as its own cluster. That's not saying much compared to Vancouver - the data shows they are completely different cities.
#     </li>
#         <li>If I want to reside in an area of Vancouver with the most outdoor recreation-friendly activities, as I did in Toronto, I should start looking first in the North West / Stanley Park area.
#     </li>
#   <li>Climate looks like it plays a significant role in the top 10 types of venues of the respective mega cities, and these venues seem to speak to the culture of the respective areas. This at least partially explains the significant difference in top 10 venue types.
#     </li>
# </ul>

# %% [markdown]
# ### I hope you enjoyed it!
